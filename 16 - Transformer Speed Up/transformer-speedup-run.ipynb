# %%
# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from __future__ import print_function

# %%
# !git clone https://github.com/kishkath/ERA.git -q --quiet
# Out:
# fatal: destination path 'ERA' already exists and is not an empty directory.

# %%
cd /kaggle/working/ERA/16 - Transformer Speed Up
# Out:
# /kaggle/working/ERA/16 - Transformer Speed Up

# %%
import os
print(os.getcwd())
# Out:
# /kaggle/working/ERA/16 - Transformer Speed Up

# %%
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 64
cfg['preload'] = None
cfg['num_epochs'] = 25

from train import train_model
import torch
torch.cuda.amp.autocast(enabled=True)

train_model(cfg)
# Out:
# 2024-04-02 04:30:37.107915: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 04:30:37.108030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 04:30:37.248893: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using device: cuda
# Downloading builder script:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/7.98k [00:00<?, ?B/s]
# Downloading and preparing dataset opus_books/en-fr (download: 11.45 MiB, generated: 31.47 MiB, post-processed: Unknown size, total: 42.92 MiB) to /root/.cache/huggingface/datasets/opus_books/en-fr/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf...
# Downloading data:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/127085 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-fr/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Before pre-processing entire-dataset:  114376
# After preprocessing entire-dataset:  63704
# Before pre-processing entire-dataset:  12709
# After preprocessing entire-dataset:  7080
# Max length of source sentence: 471
# Max length of target sentence: 482
# Processing Epoch 00: 100%|██████████| 996/996 [09:33<00:00,  1.74it/s, loss=5.054]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: D’Artagnan offered his arm to Mme. Bonacieux, who willingly took it, half laughing, half trembling, and both gained the top of Rue de la Harpe.
#     TARGET: D'Artagnan offrit son bras à Mme Bonacieux, qui s'y suspendit, moitié rieuse, moitié tremblante, et tous deux gagnèrent le haut de la rue de La Harpe.
#  PREDICTED: D ' Artagnan se de la de la , et il était un , et les , et les , et les , et les .
# --------------------------------------------------------------------------------
#     SOURCE: "Men in this place?" cried the reporter.
#     TARGET: -- Des hommes en cet endroit? s'écria le reporter.
#  PREDICTED: -- Et ce que le homme ? dit le .
# --------------------------------------------------------------------------------
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `CharErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `CharErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `WordErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `WordErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `BLEUScore` from `torchmetrics` was deprecated and will be removed in 2.0. Import `BLEUScore` from `torchmetrics.text` instead.
#   _future_warning(
# Processing Epoch 01: 100%|██████████| 996/996 [09:33<00:00,  1.74it/s, loss=4.532]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: The next day I related the night's events to Conseil and the Canadian, events that had aroused my curiosity to a fever pitch.
#     TARGET: Le lendemain, je racontai à Conseil et au Canadien les événements de cette nuit, qui surexcitaient ma curiosité au plus haut point.
#  PREDICTED: Le lendemain , je suis au milieu de la nuit de la nuit et le _Nautilus_ , qu ' on avait été à mon esprit .
# --------------------------------------------------------------------------------
#     SOURCE: "You are sure there is nobody there?" said the stranger.
#     TARGET: «Vous êtes sûr qu'il n'y a personne? dit l'inconnu.
#  PREDICTED: -- Vous avez - il donc là ? dit le jeune homme .
# --------------------------------------------------------------------------------
# Processing Epoch 02: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=4.169]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He first came to order something, and thenhe called frequently.
#     TARGET: Il était venu commander quelque chose, et puisil est revenu souvent.
#  PREDICTED: Il se mit à faire quelque chose , et il s ’ y a fait .
# --------------------------------------------------------------------------------
#     SOURCE: I bethought myself of an expedient.
#     TARGET: Je pris un expédient.
#  PREDICTED: Je me d ' un peu de nouveau .
# --------------------------------------------------------------------------------
# Processing Epoch 03: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=3.914]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: With me, all the men went down this morning.
#     TARGET: Chez moi, tous les hommes sont descendus, ce matin.
#  PREDICTED: Avec moi , tous les hommes se .
# --------------------------------------------------------------------------------
#     SOURCE: "Silence! This violence is all most repulsive:" and so, no doubt, she felt it.
#     TARGET: -- Taisez-vous, votre violence me fait horreur!»
#  PREDICTED: -- Silence ! cette violence est tout de plus , et non , non , sans doute .
# --------------------------------------------------------------------------------
# Processing Epoch 04: 100%|██████████| 996/996 [09:33<00:00,  1.74it/s, loss=3.906]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Then die!−−I will tell you.
#     TARGET: Alors, meurs ! – Je vais te dire.
#  PREDICTED: Puis , je te .
# --------------------------------------------------------------------------------
#     SOURCE: There is a reason for everything unaccountable which has happened here, and that reason I shall discover.
#     TARGET: Il y a une cause à tout ce qui se passe d'inexplicable ici, et cette cause, je la découvrirai.
#  PREDICTED: Il y a une raison de tout ce qui est arrivé ici , et que je serai le droit de la raison .
# --------------------------------------------------------------------------------
# Processing Epoch 05: 100%|██████████| 996/996 [09:33<00:00,  1.74it/s, loss=3.680]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "What victim?" said Judge Obadiah.
#     TARGET: « Quelle victime ? demanda-t-il.
#  PREDICTED: -- Quel victime ? dit le juge en route .
# --------------------------------------------------------------------------------
#     SOURCE: Her ladyship was highly incensed.
#     TARGET: Sa Grâce était en grand courroux.
#  PREDICTED: Son Éminence était très fort .
# --------------------------------------------------------------------------------
# Processing Epoch 06: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=3.110]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Porthos went away after having appointed a meeting with the procurator’s wife in the cloister of St. Magloire.
#     TARGET: Porthos sortit après avoir donné rendez-vous à la procureuse dans le cloître Saint-Magloire.
#  PREDICTED: Julien s ’ approcha d ’ avoir reçu un rendez - vous avec la femme de Saint - Germain .
# --------------------------------------------------------------------------------
#     SOURCE: His father was dead against the business from the beginning, and spoke quite unfeelingly on the subject.
#     TARGET: Des le début, son pere désapprouva son entreprise, qu’il critiquait sans retenue.
#  PREDICTED: Son père était mort contre le commencement du commencement , et parlait tout à coup .
# --------------------------------------------------------------------------------
# Processing Epoch 07: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=3.179]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Every one soon had her ammunition at her feet, and the battle of stones began.
#     TARGET: Bientôt, chacun eut a ses pieds des munitions, la bataille a coups de pierres commença.
#  PREDICTED: Chaque fois , tous ses munitions , les pieds de leur bataille se mirent de pierres .
# --------------------------------------------------------------------------------
#     SOURCE: Cette cendre était noire et compacte et telle que seul un cigare de Trichinopoli peut en produire de semblable.
#     TARGET: It was dark in colour and flakey—such an ash as is only made by a Trichinopoly.
#  PREDICTED: and .
# --------------------------------------------------------------------------------
# Processing Epoch 08: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=3.198]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "That's driving Epidaurus and Chaldea very fast," replied the physician with a grin.
#     TARGET: – C’est mener grand train Épidaurus et la Chaldée, répliqua le médecin en ricanant.
#  PREDICTED: -- C ' est bien de voir Conseil et de très vite , répondit le médecin d ' un grimace .
# --------------------------------------------------------------------------------
#     SOURCE: There was nothing tender in his sentiments at this first moment.
#     TARGET: Il n’y avait rien de tendre dans ses sentiments de ce premier moment.
#  PREDICTED: Il n ' y avait rien de tendre dans ce premier moment .
# --------------------------------------------------------------------------------
# Processing Epoch 09: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.865]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: It was a glorious night.
#     TARGET: C’était une nuit splendide.
#  PREDICTED: C ' était une nuit royale .
# --------------------------------------------------------------------------------
#     SOURCE: "And that's just the point," added Pencroft, "I don't know if we have done right to bring him here."
#     TARGET: «Et c'est au point, ajouta Pencroff, que je ne sais pas si nous avons bien fait de l'amener ici.
#  PREDICTED: -- Et c ' est juste , ajouta Pencroff , je ne sais pas si nous l ' avons fait raison de le faire faire .
# --------------------------------------------------------------------------------
# Processing Epoch 10: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.853]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "It is he!" cried d’Artagnan, pale with anger, and with the sweat on his brow, "it is he! let me overtake him!" "He?
#     TARGET: -- C'est lui! s'écria d'Artagnan, pâle de colère et la sueur sur le front, c'est lui! laissez-moi le rejoindre!
#  PREDICTED: -- C ' est lui , s ' écria d ' Artagnan pâle , pâle et avec la sueur sur son front , il me laisse mourir , et qu ' il me laisse mourir !
# --------------------------------------------------------------------------------
#     SOURCE: "By my soul, you had made me forget all that, dear Constance! Yes, you are right; a furlough is needful."
#     TARGET: -- Sur mon âme, vous m'aviez fait oublier tout cela, chère Constance! oui, vous avez raison, il me faut un congé.
#  PREDICTED: -- Par mon âme , vous m ' avez fait oublier tout cela , mon cher Athos , vous avez raison ; un peu , un peu .»
# --------------------------------------------------------------------------------
# Processing Epoch 11: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.861]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: In a few minutes they arrived there, but the prisoner remembered nothing, and it appeared that he had lost consciousness of everything.
#     TARGET: En quelques minutes, tous y arrivèrent; mais là, le prisonnier ne reconnut rien, et il semblait qu'il eût perdu conscience de toutes choses!
#  PREDICTED: En quelques instants , ils arrivèrent , mais la prisonnière ne se rappelait rien , et il parut qu ’ il avait perdu tout sentiment de suite .
# --------------------------------------------------------------------------------
#     SOURCE: I protest to you that 'twas not I who wrote the matter to Monseigneur do Guyenne, but Monsieur le Cardinal Balue."
#     TARGET: Je vous proteste que ce n’est pas moi qui ai écrit la chose à monseigneur de Guyenne, mais monsieur le cardinal La Balue !
#  PREDICTED: Je vous prie de ne pas avoir écrit ce qui a l ' affaire de , mais M . le baron Trampe en route .
# --------------------------------------------------------------------------------
# Processing Epoch 12: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.765]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: She allowed the vessel to pass Lorient and Brest without repeating her request to the captain, who, on his part, took care not to remind her of it.
#     TARGET: Elle laissa donc passer Lorient et Brest sans insister près du capitaine, qui, de son côté, se garda bien de lui donner l'éveil.
#  PREDICTED: Elle laissa passer le navire à la campagne et sans répéter sans répéter à son demande qui , pour sa part , ne se retira pas de la rassurer .
# --------------------------------------------------------------------------------
#     SOURCE: "Tobacco! real tobacco!"
#     TARGET: «Du tabac! Du vrai tabac!
#  PREDICTED: -- Du pain ! véritable !
# --------------------------------------------------------------------------------
# Processing Epoch 13: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.555]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: As we stood, waiting for the eventful moment, I heard someone behind call out:
#     TARGET: Nous attendions tous le moment fatidique, quand une voix lança derriere nous :
#  PREDICTED: Comme nous étions arrivés au moment du premier personnage , j ' entendis quelqu ' un qui s ' appelait :
# --------------------------------------------------------------------------------
#     SOURCE: "Thank you, Jock, thank you," said she. "It was like your kindness to bring the message.
#     TARGET: -- Merci, Jock, merci, dit-elle, vous avez été bien bon de faire cette commission.
#  PREDICTED: « Merci , madame , dit - elle , c ' était comme votre bonté pour amener le message .
# --------------------------------------------------------------------------------
# Processing Epoch 14: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.245]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "I wish you to obtain for me, from Monsieur Dessessart, leave of absence for fifteen days."
#     TARGET: -- Je désire que vous obteniez pour moi, de M. des Essarts, un congé de quinze jours.
#  PREDICTED: -- Je désire vous obtenir pour moi , de M . de Tréville , quittez quinze jours pour un jour .
# --------------------------------------------------------------------------------
#     SOURCE: Captain Nemo had left his stateroom.
#     TARGET: Le capitaine Nemo avait quitté sa chambre.
#  PREDICTED: Le capitaine Nemo avait quitté son salon .
# --------------------------------------------------------------------------------
# Processing Epoch 15: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.384]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: In 1839 the Englishman Balleny discovered the Sabrina Coast at the edge of the polar circle.
#     TARGET: En 1839, l'Anglais Balleny découvrait la terre Sabrina, sur la limite du cercle polaire.
#  PREDICTED: En 1825 , l ' Anglais découvrit le du bord du passage du .
# --------------------------------------------------------------------------------
#     SOURCE: This demand impressed the Mayor.
#     TARGET: Cette demande frappa le maire.
#  PREDICTED: Cette demande fit réfléchir les truands .
# --------------------------------------------------------------------------------
# Processing Epoch 16: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.425]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: – La révolte est apaisée !
#     TARGET: "The revolt is suppressed!"
#  PREDICTED: " The Duchessa is too !"
# --------------------------------------------------------------------------------
#     SOURCE: CHAPTER IV
#     TARGET: *c IV
#  PREDICTED: CHAPITRE IV
# --------------------------------------------------------------------------------
# Processing Epoch 17: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.296]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He put the matches ready, the candlestick, a book, arranged her nightgown, turned back the bedclothes.
#     TARGET: Il plaçait les allumettes, le bougeoir, un livre, disposait sa camisole, ouvrait les draps.
#  PREDICTED: Il prit les allumettes , le crayon , alluma un livre , ramenait sa Seine , tourna les draps .
# --------------------------------------------------------------------------------
#     SOURCE: "Joe!"
#     TARGET: « Joe !
#  PREDICTED: Joe !»
# --------------------------------------------------------------------------------
# Processing Epoch 18: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=2.014]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: — Permettez-moi seulement de m’asseoir, dit le prisonnier en joignant l’action a la parole.
#     TARGET: "I'll sit down, with your leave," the prisoner said, suiting the action to the word.
#  PREDICTED: " Give me food ," the other said , into the action .
# --------------------------------------------------------------------------------
#     SOURCE: "I don't know, officer," replied the Parsee, listening attentively to a confused murmur which came through the thick branches.
#     TARGET: -- Je ne sais, mon officier », répondit le Parsi, en prêtant l'oreille à un murmure confus qui passais sous l'épaisse ramure.
#  PREDICTED: -- Je ne sais pas , officier , répondit le reporter , ayant attentivement l ' air confus qui venait par les branches .
# --------------------------------------------------------------------------------
# Processing Epoch 19: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=1.978]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "I have an idea about them."
#     TARGET: -- J'ai une idée sur eux.
#  PREDICTED: -- J ' en ai une idée .
# --------------------------------------------------------------------------------
#     SOURCE: "Over to somebody with better aim!" the commander shouted. "And $500.00 to the man who can pierce that infernal beast!"
#     TARGET: « A un autre plus adroit ! cria le commandant, et cinq cents dollars à qui percera cette infernale bête ! »
#  PREDICTED: -- À un mieux , répondit le commandant , et Gédéon Spilett , Nab à l ' homme qui peut être gourmand ce maudit !
# --------------------------------------------------------------------------------
# Processing Epoch 20: 100%|██████████| 996/996 [09:34<00:00,  1.73it/s, loss=1.941]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: No doubt the presence of the Nautilus, even more fearsome than itself, and which it couldn't grip with its mandibles or the suckers on its arms.
#     TARGET: Sans doute de la présence de ce _Nautilus_, plus formidable que lui, et sur lequel ses bras suceurs ou ses mandibules n'avaient aucune prise.
#  PREDICTED: Sans doute la présence du cardinal , plus même que lui - même , et qui ne pouvait tenir sa volonté avec des jésuites ou les bras de son équipage .
# --------------------------------------------------------------------------------
#     SOURCE: Satisfied with this discovery which confirmed all his suspicions, Athos returned to the hotel, and found Planchet impatiently waiting for him.
#     TARGET: Satisfait de cette découverte qui confirmait tous ses soupçons, Athos revint à l'hôtel et trouva Planchet qui l'attendait avec impatience.
#  PREDICTED: Julien de cette découverte qui tous ses soupçons , revint vers l ’ hôtel , et Julien l ’ attendait .
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:619, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     618 with _open_zipfile_writer(f) as opened_zipfile:
# --> 619     _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     620     return
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:853, in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#     852 num_bytes = storage.nbytes()
# --> 853 zip_file.write_record(name, storage.data_ptr(), num_bytes)
#
# RuntimeError: [enforce fail at inline_container.cc:588] . PytorchStreamWriter failed writing file data/749: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 11
#       8 import torch
#       9 torch.cuda.amp.autocast(enabled=True)
# ---> 11 train_model(cfg)
#
# File /kaggle/working/ERA/16 - Transformer Speed Up/train.py:257, in train_model(config)
#     255 # Save the model at the end of every epoch
#     256 model_filename = get_weights_file_path(config, f"{epoch:02d}")
# --> 257 torch.save({
#     258     'epoch': epoch,
#     259     'model_state_dict': model.state_dict(),
#     260     'optimizer_state_dict': optimizer.state_dict(),
#     261     'global_step': global_step
#     262 }, model_filename)
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:618, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     615 _check_save_filelike(f)
#     617 if _use_new_zipfile_serialization:
# --> 618     with _open_zipfile_writer(f) as opened_zipfile:
#     619         _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     620         return
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:466, in _open_zipfile_writer_file.__exit__(self, *args)
#     465 def __exit__(self, *args) -> None:
# --> 466     self.file_like.write_end_of_file()
#     467     if self.file_stream is not None:
#     468         self.file_stream.close()
#
# RuntimeError: [enforce fail at inline_container.cc:424] . unexpected pos 847733312 vs 847733204

# %%
# !pip install datasets -Uw
