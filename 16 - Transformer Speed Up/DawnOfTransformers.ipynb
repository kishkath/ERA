# %%
# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2


# # Future print function
# from __future__ import print_function

# # Load modules/models from EVA course
# !git clone https://github.com/sujitojha1/ERA1 -q --quiet
# !mv ERA1/Session15/* .
# !rm -rf ERA1

# print("Loaded Modules and Models")

# # Installing Library
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet

# # For inline matplotlib plotting
# %matplotlib inline


# from config import get_config
# cfg = get_config()
# cfg['batch_size'] = 6
# cfg['preload'] = None
# cfg['num_epochs'] = 30

# from train import train_model

# train_model(cfg)

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from __future__ import print_function

# %%
# %cd /content/drive/MyDrive/session15/scripts/content/codes/

import os
print(os.getcwd())
# Out:
# /content/drive/MyDrive/session15/scripts/content/codes
# /content/drive/MyDrive/session15/scripts/content/codes

# %%
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.4/840.4 kB 5.3 MB/s eta 0:00:00

# %%
import os
print(os.getcwd())

from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 30

from train import train_model

train_model(cfg)
# Out:
# /content/drive/MyDrive/session15/scripts/content/codes
# Using device: cuda
# Max length of source sentence: 309
# Max length of target sentence: 274
# Processing Epoch 00: 100%|██████████| 4850/4850 [25:39<00:00,  3.15it/s, loss=6.355]
# --------------------------------------------------------------------------------
#     SOURCE: There is a thought that for strength should avail me, Though both of shelter and kindred despoiled; Heaven is a home, and a rest will not fail me; God is a friend to the poor orphan child."
#     TARGET: "Questo pensiero deve infondermi coraggio, benché non abbia né ricovero né genitori. Il cielo è la mia casa, e lassù non mi mancherà il riposo.
#  PREDICTED: Non è una volta , e non , ma non , ma non , ma non , ma non , ma non .
# --------------------------------------------------------------------------------
#     SOURCE: She was afraid of giving way to these delirious thoughts.
#     TARGET: Aveva paura di lasciarsi andare a questo vaneggiamento.
#  PREDICTED: Il signor Rochester era un ’ altra .
# --------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `CharErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `CharErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `WordErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `WordErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `BLEUScore` from `torchmetrics` was deprecated and will be removed in 2.0. Import `BLEUScore` from `torchmetrics.text` instead.
#   _future_warning(
# Processing Epoch 01: 100%|██████████| 4850/4850 [25:39<00:00,  3.15it/s, loss=5.702]
# --------------------------------------------------------------------------------
#     SOURCE: CHAPTER VII
#     TARGET: VII
#  PREDICTED: Cap .
# --------------------------------------------------------------------------------
#     SOURCE: 'I knew! I knew!' he cried, repeating his favourite phrase, and seizing her hand, which was caressing his hair, he pressed her palm to his mouth, covering it with kisses.
#     TARGET: — Lo sapevo, lo sapevo! — ripeteva lui la sua frase preferita e, presale la mano che gli carezzava i capelli, cominciò a premerne la palma sulla bocca e a baciarla.
#  PREDICTED: — Io mi pare — disse , — e io mi la mano e la mano , e si mise a guardare il viso di nuovo e si mise a guardare il viso .
# --------------------------------------------------------------------------------
# Processing Epoch 02: 100%|██████████| 4850/4850 [25:39<00:00,  3.15it/s, loss=5.400]
# --------------------------------------------------------------------------------
#     SOURCE: I never thought it would be so interesting.
#     TARGET: Non avrei mai pensato che la cosa fosse così interessante.
#  PREDICTED: Non mi pare che non era nulla .
# --------------------------------------------------------------------------------
#     SOURCE: Levin did not hear what she was speaking about while she leaned toward her brother but was struck by the change in her expression.
#     TARGET: Levin non sentiva di cosa ella parlasse, dopo essersi tutta piegata verso il fratello, ma fu sorpreso del mutamento della sua espressione.
#  PREDICTED: Levin non poteva dire che cosa era qualcosa di strano , ma la conversazione era la sua conversazione .
# --------------------------------------------------------------------------------
# Processing Epoch 03:  70%|███████   | 3412/4850 [18:03<07:35,  3.16it/s, loss=4.195]
