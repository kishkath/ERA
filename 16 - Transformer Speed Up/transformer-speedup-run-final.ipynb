# %%
# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from __future__ import print_function

# %%
# !rm -r /kaggle/working/ERA
# Out:
# rm: cannot remove '/kaggle/working/ERA': No such file or directory

# %%
# !git clone https://github.com/kishkath/ERA.git -q --quiet

# %%
cd /kaggle/working/ERA/16 - Transformer Speed Up
# Out:
# /kaggle/working/ERA/16 - Transformer Speed Up

# %%
import os
print(os.getcwd())
# Out:
# /kaggle/working/ERA/16 - Transformer Speed Up

# %%
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 64
cfg['preload'] = None
cfg['num_epochs'] = 30

from train import train_model
import torch
torch.cuda.amp.autocast(enabled=True)

train_model(cfg)
# Out:
# 2024-04-16 04:28:18.838257: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-16 04:28:18.838380: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-16 04:28:18.969130: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using device: cuda
# Downloading readme:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# Downloading data: 100%|██████████| 21.0M/21.0M [00:00<00:00, 33.7MB/s]
# Generating train split:   0%|          | 0/127085 [00:00<?, ? examples/s]
# Before pre-processing entire-dataset:  114376
# After preprocessing entire-dataset:  63688
# Before pre-processing entire-dataset:  12709
# After preprocessing entire-dataset:  7096
# Max length of source sentence: 471
# Max length of target sentence: 482
# Processing Epoch 00: 100%|██████████| 996/996 [16:44<00:00,  1.01s/it, loss=5.698]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Yet they will make the attempt; they will flutter their wings; they will call upon each other.
#     TARGET: Elles essayeront cependant, elles battront des ailes, elles s’appelleront.
#  PREDICTED: Le capitaine , il se , et les , les , et les .
# --------------------------------------------------------------------------------
#     SOURCE: They were of great service to me, and especially that one incidentally truthful piece of biography of Stapleton's.
#     TARGET: Ils me furent très utiles, notamment celui qui m’apprit quelque chose de la biographie de Stapleton.
#  PREDICTED: Le de la , et et le , et le de la .
# --------------------------------------------------------------------------------
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `CharErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `CharErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `WordErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `WordErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `BLEUScore` from `torchmetrics` was deprecated and will be removed in 2.0. Import `BLEUScore` from `torchmetrics.text` instead.
#   _future_warning(
# Processing Epoch 01: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=4.631]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "By the way, I fancy I remember that you used to have, in Paris, alittle portrait of Marechal, in the drawing-room."
#     TARGET: --Dis donc, j'ai cru me rappeler qu'il y avait autrefois, à Paris, unpetit portrait de Maréchal dans notre salon.
#  PREDICTED: -- En effet , je vous ai bien que je vous ai vu à votre , de M . de Rênal , à la mer .
# --------------------------------------------------------------------------------
#     SOURCE: But I expect he only says this to comfort me.
#     TARGET: Mais je crois qu’il ne dit cela que pour me consoler.
#  PREDICTED: Mais je ne me dis pas que je me .
# --------------------------------------------------------------------------------
# Processing Epoch 02: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=4.126]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Well said," cried the people, "and let us begin the hanging with his sergeants."
#     TARGET: – Bien dit, cria le peuple, et entamons la pendaison par ses sergents. »
#  PREDICTED: -- Eh bien , dit le diable , et nous avec son fils .
# --------------------------------------------------------------------------------
#     SOURCE: The turn of the rocks sheltered them from the wind, and they could breathe after this walk or rather run of a quarter of an hour.
#     TARGET: Le retour du rocher les abritait contre le vent, et ils respiraient après cette marche d'un quart d'heure, qui avait été plutôt une course.
#  PREDICTED: Le tour de la mer les de la mer , et ils étaient toujours après ce moment ou un quart d ' une heure d ' une heure .
# --------------------------------------------------------------------------------
# Processing Epoch 03: 100%|██████████| 996/996 [16:52<00:00,  1.02s/it, loss=3.839]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Then they become our friends, or rather our guests at table.
#     TARGET: Alors elles deviennent nos amies ou plutôt nos commensales.
#  PREDICTED: Puis , ils nos amis , ou un peu de table .
# --------------------------------------------------------------------------------
#     SOURCE: Milady was habitually pale; her complexion might therefore deceive a person who saw her for the first time.
#     TARGET: Milady était habituellement pâle; son teint pouvait donc tromper une personne qui la voyait pour la première fois.
#  PREDICTED: Julien était de l ’ air pâle ; son air , le vit bien qu ’ elle vit la première fois .
# --------------------------------------------------------------------------------
# Processing Epoch 04: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=3.442]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: I ought to be just, and to feel neither hatred nor love for anyone.
#     TARGET: Je devrais être juste, et n’avoir ni haine ni amour pour personne.
#  PREDICTED: Je voudrais bien être , et pour ne pas croire ni une haine .
# --------------------------------------------------------------------------------
#     SOURCE: Maintenant, a votre tour ; qu’avez-vous a confesser ?
#     TARGET: What have you to confess now?
#  PREDICTED: " What , you are your tour , what you are ?"
# --------------------------------------------------------------------------------
# Processing Epoch 05: 100%|██████████| 996/996 [16:50<00:00,  1.01s/it, loss=3.318]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Gracious!" Conseil put in. "Suppose one day some volcanic upheaval raises these two barriers back above the waves!"
#     TARGET: -- Eh ! fit Conseil, si quelque poussée volcanique relevait un jour ces deux barrières au-dessus des flots !
#  PREDICTED: « ! fit Conseil , un jour , un jour , un jour ces deux lignes ! »
# --------------------------------------------------------------------------------
#     SOURCE: But it was around the Pope of the Fools that all the musical riches of the epoch were displayedin a magnificent discord.
#     TARGET: Mais c’est autour du pape des fous que se déployaient, dans une cacophonie magnifique, toutes les richesses musicales de l’époque.
#  PREDICTED: Mais c ’ était le pape des qui toutes les de l ’ arrivée du moment , une .
# --------------------------------------------------------------------------------
# Processing Epoch 06: 100%|██████████| 996/996 [16:52<00:00,  1.02s/it, loss=3.310]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Because I promised her I would."
#     TARGET: --Parce que je lui ai promis d'y aller.
#  PREDICTED: -- Parce que j ' ai promis de l ' avoir vu .
# --------------------------------------------------------------------------------
#     SOURCE: "My brave young man, I will blow out your brains.
#     TARGET: -- Mon brave jeune homme, je vais vous casser la tête.
#  PREDICTED: -- Mon brave homme , je votre tête .
# --------------------------------------------------------------------------------
# Processing Epoch 07: 100%|██████████| 996/996 [16:52<00:00,  1.02s/it, loss=3.347]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Only two loaves, Monsieur Maigrat.
#     TARGET: —Rien que deux pains, monsieur Maigrat.
#  PREDICTED: -- Seulement deux livres , monsieur le chevalier .
# --------------------------------------------------------------------------------
#     SOURCE: In June the wheat was already high, of a blue green, which contrasted with the black green of the beetroots.
#     TARGET: En juin, les blés étaient grands déja, d'un vert bleu qui tranchait sur le vert noir des betteraves.
#  PREDICTED: Le juin , le poisson était déjà haut d ' un bleu bleu , qui se rappelait avec les noirs du _Nautilus_ .
# --------------------------------------------------------------------------------
# Processing Epoch 08: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=3.343]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "For the men in green: it was a proper moonlight evening for them.
#     TARGET: -- Eh! mais des hommes verts.
#  PREDICTED: -- Pour les hommes , ce soir , il y avait une lune de lune pour eux .
# --------------------------------------------------------------------------------
#     SOURCE: "I have heard so much."
#     TARGET: – Oui.
#  PREDICTED: -- J ' ai entendu parler .
# --------------------------------------------------------------------------------
# Processing Epoch 09: 100%|██████████| 996/996 [16:50<00:00,  1.01s/it, loss=3.432]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Unaccountable indeed," answered the engineer, who did not appear desirous to prolong the conversation.
#     TARGET: -- Inexplicable, en effet, répondit l'ingénieur, qui semblait ne pas vouloir prolonger cette conversation.
#  PREDICTED: -- En effet , répondit le reporter , qui ne voulait pas se rendre à la conversation .
# --------------------------------------------------------------------------------
#     SOURCE: I stared at him.
#     TARGET: Je le regardai.
#  PREDICTED: Je le regardai .
# --------------------------------------------------------------------------------
# Processing Epoch 10: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=2.708]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: When I remembered how far I had once been admitted to his confidence, I could hardly comprehend his present frigidity.
#     TARGET: en me rappelant tout ce qu'il m'avait dit un jour, j'avais peine à comprendre sa froideur actuelle.
#  PREDICTED: Quand je me rappelais comme une fois , j ' avais été obligé de me le tromper , je ne pouvais jamais comprendre son parti .
# --------------------------------------------------------------------------------
#     SOURCE: They didn't understand him at first.
#     TARGET: Elles ne comprirent pas, tout d’abord.
#  PREDICTED: On ne le comprenait pas d ' abord .
# --------------------------------------------------------------------------------
# Processing Epoch 11: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=2.876]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Though Candide did not absolutely agree to this, yet he did not determine anything on that head.
#     TARGET: Candide n'en convenait pas, mais il n'assurait rien.
#  PREDICTED: Sans doute que Julien ne voulait pas penser , il ne voulait rien le moindre de cette tête .
# --------------------------------------------------------------------------------
#     SOURCE: Tell me the name of the intriguing woman who suggested it to you .. .
#     TARGET: Dis-moi le nom de l’intrigante qui te l’a suggérée…
#  PREDICTED: Dites - moi le nom de la femme qui l ’ a proposé de vous …
# --------------------------------------------------------------------------------
# Processing Epoch 12: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=2.724]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: 'I have avenged myself,' he told her.
#     TARGET: « Je me suis vengé, lui disait-il.
#  PREDICTED: – Je me suis vengé , lui dit - il .
# --------------------------------------------------------------------------------
#     SOURCE: She did not speak to him again for six weeks.
#     TARGET: Elle ne lui adressa pas la parole de six semaines.
#  PREDICTED: Elle ne lui parlait pas depuis six semaines .
# --------------------------------------------------------------------------------
# Processing Epoch 13: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=2.306]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: They looked in that direction.
#     TARGET: On regarda dans cette direction.
#  PREDICTED: On regardait ce côté .
# --------------------------------------------------------------------------------
#     SOURCE: I know my Maker sanctions what I do. For the world's judgment--I wash my hands thereof.
#     TARGET: Je sais que mon Créateur m'approuve;
#  PREDICTED: Je sais mon qui me reste , moi , au jugement du monde , je mes mains .
# --------------------------------------------------------------------------------
# Processing Epoch 14: 100%|██████████| 996/996 [16:51<00:00,  1.02s/it, loss=2.553]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Be still, then," said Dr. Vanderhaghen, who had followed to attend to Jeanlin.
#     TARGET: —Tais-toi donc! dit le docteur Vanderhaghen, qui avait suivi pour panser Jeanlin.
#  PREDICTED: -- Allons donc , dit Mme Bonacieux , qui avait suivi à Jean pour le revoir .
# --------------------------------------------------------------------------------
#     SOURCE: Huge shadows fell from the trees, and the water ran black at the edges.
#     TARGET: De grandes ombres tombaient des arbres, et les eaux étaient noires sur les bords.
#  PREDICTED: Des ombres tombaient des arbres , et l ' eau bénite se dressait au Voreux .
# --------------------------------------------------------------------------------
# Processing Epoch 15: 100%|██████████| 996/996 [16:52<00:00,  1.02s/it, loss=2.122]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He was completely absorbed; he made only a half-hearted response to the keen affection that she showed for him.
#     TARGET: Son âme était absorbée ; il ne répondait qu’à demi à la vive tendresse qu’elle lui témoignait.
#  PREDICTED: Il était complètement absorbé ; il fit une demi - réponse à l ’ air sévère de sa tendresse qu ’ elle lui montra .
# --------------------------------------------------------------------------------
#     SOURCE: Prudence wanted to go and ask your father's friend for money, but I would not let her.
#     TARGET: Prudence voulait demander de l'argent à l'ami de votre père, je m'y suis opposée."
#  PREDICTED: Marguerite voulut partir et demander l ' ami de votre père , mais je ne la pas .
# --------------------------------------------------------------------------------
# Processing Epoch 16: 100%|██████████| 996/996 [16:49<00:00,  1.01s/it, loss=2.227]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: CHAPTER 20
#     TARGET: XX
#  PREDICTED: CHAPITRE XX
# --------------------------------------------------------------------------------
#     SOURCE: As for me, I looked at her with a mingling of love and terror, as I thought of all that I was ready to suffer for her sake.
#     TARGET: A quoi? je l'ignore; moi, je la regardais avec amour et presque avec terreur en pensant à cee que j'étais prêt à souffrir pour elle.
#  PREDICTED: Pour moi , je la regardais d ' un air plein de amour et de terreur , comme je croyais que j ' étais prêt à m ' amuser .
# --------------------------------------------------------------------------------
# Processing Epoch 17: 100%|██████████| 996/996 [16:50<00:00,  1.01s/it, loss=2.129]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "You may depend upon my not mentioning it."
#     TARGET: – Vous pouvez compter sur ma discrétion.
#  PREDICTED: -- Vous pouvez compter sur ma promesse que vous l ' avez parler .
# --------------------------------------------------------------------------------
#     SOURCE: I have let him know that M. Valenod has my last word.'
#     TARGET: Je lui ai fait dire que M. de Valenod a mon dernier mot.
#  PREDICTED: Je le connais que M . Valenod a ma dernière parole .
# --------------------------------------------------------------------------------
# Processing Epoch 18: 100%|██████████| 996/996 [16:50<00:00,  1.01s/it, loss=2.190]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Ah! it is hunger that takes the courage from a man.
#     TARGET: Ah! c'est la faim qui ôte à l'homme toute énergie.
#  PREDICTED: Ah ! il est la faim qui s ' élargit à un homme .
# --------------------------------------------------------------------------------
#     SOURCE: Seulement, dans un cas de ce genre, l’important est de raisonner a rebours.
#     TARGET: In solving a problem of this sort, the grand thing is to be able to reason backwards.
#  PREDICTED: Felton , in a quarter of this hour , the important était de lui donner un passeport .
# --------------------------------------------------------------------------------
# Processing Epoch 19: 100%|██████████| 996/996 [16:49<00:00,  1.01s/it, loss=2.133]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Athos took the paper, returned the pistol to his belt, approached the lamp to be assured that it was the paper, unfolded it, and read: Dec. 3, 1627
#     TARGET: Athos prit le papier, repassa le pistolet à sa ceinture, s'approcha de la lampe pour s'assurer que c'était bien celui-là, le déplia et lut:
#  PREDICTED: Emma prit le papier , rendit le pistolet à sa ceinture , approcha de la lampe , qui était l ’ avouer , le papier , en la retira ; et lut :
# --------------------------------------------------------------------------------
#     SOURCE: She knew him.
#     TARGET: Elle le connaissait...
#  PREDICTED: Elle le connaissait .
# --------------------------------------------------------------------------------
# Processing Epoch 20: 100%|██████████| 996/996 [16:48<00:00,  1.01s/it, loss=2.004]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: At the slightest indisposition of one of your children, you will no longer see them already in the grave.'
#     TARGET: À la moindre indisposition de vos enfants, vous ne les verrez plus dans la tombe.
#  PREDICTED: Au moindre bruit d ’ une de vos enfants , vous ne les verrez plus par la tombe .
# --------------------------------------------------------------------------------
#     SOURCE: "Let us make another trial," resumed the vagabond.
#     TARGET: – Essayons encore une fois », reprit le truand.
#  PREDICTED: « un autre essai , reprit l ’ abbé .
# --------------------------------------------------------------------------------
# Processing Epoch 21: 100%|██████████| 996/996 [16:48<00:00,  1.01s/it, loss=2.063]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Again the poor man groaned; he looked as if he dared not move; fear, either of death or of something else, appeared almost to paralyse him.
#     TARGET: La crainte de la mort, ou peut-être de quelque autre chose, semblait le paralyser.
#  PREDICTED: Le pauvre homme gronda . Il ne prit pas garde de s ' éloigner ; la peur , ne lui sembla pas une mort , de plus une autre chose .
# --------------------------------------------------------------------------------
#     SOURCE: There's an hour's wait there.
#     TARGET: Il y a une heure d’arrêt.
#  PREDICTED: Voilà une heure de l ' heure de l ' attendre .
# --------------------------------------------------------------------------------
# Processing Epoch 22: 100%|██████████| 996/996 [16:48<00:00,  1.01s/it, loss=1.881]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Perhaps it is a word which she believes to be endowed with some magic and secret virtue.
#     TARGET: C’est peut-être un mot qu’elle croit doué de quelque vertu magique et secrète.
#  PREDICTED: « Ce n ’ est peut - être qu ’ elle pense qu ’ elle doit être doué d ’ une vertu et secrète .
# --------------------------------------------------------------------------------
#     SOURCE: "Nothing to be done there," said Fix to himself, concealing his disappointment.
#     TARGET: « Rien à faire ! » se dit le détective en dissimulant son désappointement.
#  PREDICTED: — Rien ne peut se faire , se dit Chaval en arrivant dans son désappointement .
# --------------------------------------------------------------------------------
# Processing Epoch 23: 100%|██████████| 996/996 [16:48<00:00,  1.01s/it, loss=1.756]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Sir," I said, "you're surely unaware of the discussions that have taken place in Europe and America with yourself as the subject.
#     TARGET: « Monsieur, dis-je, vous ignorez sans doute les discussions qui ont eu lieu à votre sujet en Amérique et en Europe.
#  PREDICTED: -- Monsieur , dis - je , vous êtes sûr de l ' asphyxie du train qui ont pris lieu dans l ' Europe et de vous en autant .
# --------------------------------------------------------------------------------
#     SOURCE: Bovary turned white to fainting.
#     TARGET: Bovary devint pâle à s’évanouir.
#  PREDICTED: Grimaud se retourna blanc à demi - instant .
# --------------------------------------------------------------------------------
# Processing Epoch 24: 100%|██████████| 996/996 [16:49<00:00,  1.01s/it, loss=1.850]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "It is true, my child.
#     TARGET: --C'est vrai, mon enfant.
#  PREDICTED: — C ' est vrai , mon enfant …
# --------------------------------------------------------------------------------
#     SOURCE: Its distance still kept us from distinguishing the colors of its pennant, which was fluttering like a thin ribbon.
#     TARGET: La distance empêchait encore de distinguer les couleurs de sa flamme, qui flottait comme un mince ruban.
#  PREDICTED: Sa distance nous gardait encore de l ' épaisseur de ses minarets , ce bout un ruban ardent .
# --------------------------------------------------------------------------------
# Processing Epoch 25: 100%|██████████| 996/996 [16:50<00:00,  1.01s/it, loss=1.903]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: One's native land!--there should one live! there die!
#     TARGET: La patrie!... c'est là qu'il faut retourner!
#  PREDICTED: On est vivant , il y aurait là !
# --------------------------------------------------------------------------------
#     SOURCE: But in spite of all these specious arguments, the Marquis could not grow reconciled to abandoning the hope of a _tabouret_ for his daughter.
#     TARGET: Mais après tant de beaux raisonnements, l’âme du marquis ne pouvait s’accoutumer à renoncer à l’espoir du tabouret pour sa fille.
#  PREDICTED: Mais , malgré tous ces raisonnements , les colons ne purent se un espoir de sa fille pour un .
# --------------------------------------------------------------------------------
# Processing Epoch 26: 100%|██████████| 996/996 [16:49<00:00,  1.01s/it, loss=1.708]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Two or three distinguished themselves by real talent, and, among these, one named Chazel; but Julien felt himself repelled by them, and they by him.
#     TARGET: Deux ou trois se distinguaient par un talent réel et, entre autres, un nommé Chazel ; mais Julien se sentait de l’éloignement pour eux et eux pour lui.
#  PREDICTED: Deux ou trois mots se de mauvais talent , et , parmi ces , un poignard ; mais Julien se sentait s ’ éloigner et les par lui .
# --------------------------------------------------------------------------------
#     SOURCE: I am for those who save the state," said Bonacieux, emphatically.
#     TARGET: Je suis pour ceux qui sauvent l'État», dit avec emphase Bonacieux.
#  PREDICTED: Je suis pour ceux qui , dit avec beaucoup de l ’ air .
# --------------------------------------------------------------------------------
# Processing Epoch 27: 100%|██████████| 996/996 [16:50<00:00,  1.01s/it, loss=1.894]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: At noon on this day of November 8, we hereby begin our voyage of exploration under the waters."
#     TARGET: C'est aujourd'hui 8 novembre, à midi, que commence notre voyage d'exploration sous les eaux.
#  PREDICTED: Le jour du soir 8 novembre , on commença notre voyage de Terre - Neuve sous les eaux .
# --------------------------------------------------------------------------------
#     SOURCE: One uses fewer Bunsen cells, but they're big and strong, and experience has proven their superiority.
#     TARGET: Les éléments Bunzen sont peu nombreux, mais forts et grands, ce qui vaut mieux, expérience faite.
#  PREDICTED: Un usage se trouve plus pur , mais dont ils sont gros et vigoureux , la supériorité de la supériorité .
# --------------------------------------------------------------------------------
# Processing Epoch 28: 100%|██████████| 996/996 [16:50<00:00,  1.01s/it, loss=1.802]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Mais je l’aurai, docteur ; je vous parie deux contre un que je l’aurai.
#     TARGET: I shall have him, Doctor—I'll lay you two to one that I have him.
#  PREDICTED: I was the first time ; I offer you a which I was to love .
# --------------------------------------------------------------------------------
#     SOURCE: But the day before he lefthe was suddenly quite changed, and much softened.
#     TARGET: Mais la veille de son départ il parut soudain trèschangé, très adouci.
#  PREDICTED: Mais la veille , il se retrouva tout brusquement , tout à coup , et beaucoup s ' .
# --------------------------------------------------------------------------------
# Processing Epoch 29:  62%|██████▏   | 621/996 [10:29<06:19,  1.01s/it, loss=1.730]

# %%
# !pip install datasets -Uw
