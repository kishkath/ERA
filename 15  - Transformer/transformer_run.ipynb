# %%
# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from __future__ import print_function

# %% [markdown]
# ## **Install the ERA Package**

# %%
# !git clone https://github.com/kishkath/ERA.git -q --quiet
# Out:
# fatal: destination path 'ERA' already exists and is not an empty directory.

# %% [markdown]
# ## **Move to Transformer Directory**

# %%
# cd /kaggle/working/ERA/15 - Transformer

# %%
# import os 
# print(os.getcwd())

# %% [markdown]
# ## **Install the file packages**

# %%
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet

# %% [markdown]
# ## **Initiliaze the config parameters**

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 12

from train import train_model

train_model(cfg)
# Out:
# 2024-03-23 05:13:35.511143: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-23 05:13:35.511287: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-23 05:13:35.787479: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using device: cuda
# ...
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Max length of source sentence: 309
# ...

# %%
tensorboard --logdir="/kaggle/working/ERA/16 - Transformer Speed Up/runs/tmodel/events.out.tfevents.1711122772.6515cefce308.34.0"
# Out:
#       <iframe id="tensorboard-frame-b200125ee0191ab5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b200125ee0191ab5");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
